# %% [markdown]
# <a href="https://colab.research.google.com/github/melissagal0/Jessicaybrendalasamamosmerecemosundiezz/blob/main/Ejercicios%20individuales/P2_Ej1_KMM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math #Aquí importe la librería
#Es importante decir que la función calcula la comision, te dice el nivel que obtuviste y calcula el total a recibir
#Tambien redondea a dos decimales, la comisión que haya calculado

def calcular_comision(): #Empiezo definiendo la función
  if monto_venta < 1000: #Calculo cuando el monto es menor a 1000
    comision = round(monto_venta * 0.05,2)
    print("\nObtuviste el nivel Bronce")
    print(f"El monto de obtenido fue: {comision}")
    print(f"total a recibir: {monto_venta + comision}")

  elif monto_venta >= 1000 and monto_venta <= 5000: #Calculo cuando el monto es 1000 o 5000 o se encuentra entre estos
    comision = round(monto_venta * 0.1,2)
    print("\nObtuviste el nivel Plata")
    print(f"El monto de obtenido fue: {comision}")
    print(f"total a recibir: {monto_venta + comision}")

  else: # Calculo cuando el monto es mayor a 5000 (no necesita condición aquí)
    comision = round(monto_venta * 0.15,2)
    print("\nObtuviste el nivel Oro")
    print(f"El monto de obtenido fue: {comision}")
    print(f"total a recibir: {monto_venta + comision}")
  return ("¡¡¡Muy bien!!!")


menu_principal = True #Empezamos a construir el menú que va a contar con dos opciones.
while menu_principal: #Ponemos las opciones
  print("\nBienvenido escoge que deseas hacer hoy:")
  print("1. Calcular comision")
  print("2. Salir")

  opcion = input("\nSeleccione una opción: ")

  if opcion == "1":#Hace esto si la opción que eligio fue uno
    while True:
      nombre = input("Indique su nombre: ")
      monto_venta = round(float(input("Indique el monto: ")),2)
      if monto_venta >= 0:#Aquí validad si el mondo de venta es mayor o igual a 0.
        print(calcular_comision())#Aquí llama la función que definimos al principio.
        print("")
        break #Para terminar el ciclo

      else:#Si el monto no es mayor o igual a 0, saldrá este mensaje.
        print("\nEl monto no puede ser negativo, intenta de nuevo :(")
        break #Para terminar el ciclo


  elif opcion == "2":#Hace esto si la opción que eligio fue dos
    menu_principal = False
    print("Hasta luego, fue un gusto ayudarte.")
    break

  else:
    print("Opción no valida")#No pide el ejercicio esto, pero puede que escojan el 3 o cualquier otro número.
    print("")

#No se exactamente que explicar, pero puse comentarios en donde yo considero que es importante decir algo.
# Out:
# Bienvenido escoge que deseas hacer hoy:
# 1. Calcular comision
# 2. Salir
#
# Seleccione una opción: 1
# Indique su nombre: Karen
# Indique el monto: 40
#
# Obtuviste el nivel Bronce
# El monto de obtenido fue: 2.0
# total a recibir: 42.0
# ¡¡¡Muy bien!!!
#
#
# Bienvenido escoge que deseas hacer hoy:
# 1. Calcular comision
# 2. Salir
#
# Seleccione una opción: 2
# Hasta luego, fue un gusto ayudarte.
